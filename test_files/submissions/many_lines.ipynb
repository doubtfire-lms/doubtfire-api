# %%
for i in range(100000):
  print(f"Line {i+1} = {i+1}^2 = {(i+1)**2}")
# Out:
# Line 1 = 1^2 = 1
# Line 2 = 2^2 = 4
# Line 3 = 3^2 = 9
# Line 4 = 4^2 = 16
# Line 5 = 5^2 = 25
# Line 6 = 6^2 = 36
# Line 7 = 7^2 = 49
# Line 8 = 8^2 = 64
# Line 9 = 9^2 = 81
# Line 10 = 10^2 = 100
# Line 11 = 11^2 = 121
# Line 12 = 12^2 = 144
# Line 13 = 13^2 = 169
# Line 14 = 14^2 = 196
# Line 15 = 15^2 = 225
# Line 16 = 16^2 = 256
# Line 17 = 17^2 = 289
# Line 18 = 18^2 = 324
# Line 19 = 19^2 = 361
# Line 20 = 20^2 = 400
# Line 21 = 21^2 = 441
# Line 22 = 22^2 = 484
# Line 23 = 23^2 = 529
# Line 24 = 24^2 = 576
# Line 25 = 25^2 = 625
# Line 26 = 26^2 = 676
# Line 27 = 27^2 = 729
# Line 28 = 28^2 = 784
# Line 29 = 29^2 = 841
# Line 30 = 30^2 = 900
# Line 31 = 31^2 = 961
# Line 32 = 32^2 = 1024
# Line 33 = 33^2 = 1089
# Line 34 = 34^2 = 1156
# Line 35 = 35^2 = 1225
# Line 36 = 36^2 = 1296
# Line 37 = 37^2 = 1369
# Line 38 = 38^2 = 1444
# Line 39 = 39^2 = 1521
# Line 40 = 40^2 = 1600
# Line 41 = 41^2 = 1681
# Line 42 = 42^2 = 1764
# Line 43 = 43^2 = 1849
# Line 44 = 44^2 = 1936
# ...
